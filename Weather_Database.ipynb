# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 784

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b0892e6d6a5ef8838277813d2bd34fb2

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | airai
# Processing Record 2 of Set 1 | sunndalsora
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | haines junction
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | la romana
# Processing Record 10 of Set 1 | naqadeh
# Processing Record 11 of Set 1 | chifeng
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | yen bai
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | kefalos
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | te anau
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | san rafael
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | sullana
# Processing Record 26 of Set 1 | tucuma
# Processing Record 27 of Set 1 | yulara
# Processing Record 28 of Set 1 | sakakah
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | boda
# Processing Record 31 of Set 1 | kaitangata
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | alofi
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | sebastian
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | touho
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | khorixas
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | sao raimundo nonato
# Processing Record 44 of Set 1 | milove
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | necochea
# Processing Record 47 of Set 1 | yatou
# Processing Record 48 of Set 1 | zhovkva
# Processing Record 49 of Set 1 | jonuta
# Processing Record 50 of Set 1 | great yarmouth
# Processing Record 1 of Set 2 | lasa
# Processing Record 2 of Set 2 | sampit
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | pisco
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | wukari
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | lukovetskiy
# Processing Record 9 of Set 2 | albox
# Processing Record 10 of Set 2 | kuching
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | pelym
# Processing Record 13 of Set 2 | maple creek
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | luderitz
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | sao luis de montes belos
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | oga
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 26 of Set 2 | jiexiu
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | boende
# Processing Record 29 of Set 2 | grimshaw
# Processing Record 30 of Set 2 | talara
# Processing Record 31 of Set 2 | nouadhibou
# Processing Record 32 of Set 2 | nikolskoye
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | coahuayana
# Processing Record 35 of Set 2 | miyang
# Processing Record 36 of Set 2 | peyima
# Processing Record 37 of Set 2 | sisimiut
# Processing Record 38 of Set 2 | aksu
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | masvingo
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | poso
# Processing Record 44 of Set 2 | belmonte
# Processing Record 45 of Set 2 | praia da vitoria
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | nemuro
# Processing Record 48 of Set 2 | deder
# Processing Record 49 of Set 2 | barrow
# Processing Record 50 of Set 2 | samarai
# Processing Record 1 of Set 3 | faya
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 3 | hofn
# Processing Record 5 of Set 3 | wakefield
# Processing Record 6 of Set 3 | alice springs
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | waingapu
# Processing Record 9 of Set 3 | rawah
# Processing Record 10 of Set 3 | ineu
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | jakhal mandi
# City not found. Skipping...
# Processing Record 13 of Set 3 | chipinge
# Processing Record 14 of Set 3 | dubrovka
# Processing Record 15 of Set 3 | vaini
# Processing Record 16 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 3 | itamaraju
# Processing Record 18 of Set 3 | tura
# Processing Record 19 of Set 3 | inirida
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | lompoc
# Processing Record 23 of Set 3 | portland
# Processing Record 24 of Set 3 | salalah
# Processing Record 25 of Set 3 | mulchen
# Processing Record 26 of Set 3 | bitung
# Processing Record 27 of Set 3 | pangai
# Processing Record 28 of Set 3 | zabol
# Processing Record 29 of Set 3 | port lincoln
# Processing Record 30 of Set 3 | urusha
# Processing Record 31 of Set 3 | ranau
# Processing Record 32 of Set 3 | atuona
# Processing Record 33 of Set 3 | ouadda
# Processing Record 34 of Set 3 | chokurdakh
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | achisay
# City not found. Skipping...
# Processing Record 37 of Set 3 | zemlyansk
# Processing Record 38 of Set 3 | jamestown
# Processing Record 39 of Set 3 | sangar
# Processing Record 40 of Set 3 | ancud
# Processing Record 41 of Set 3 | araouane
# Processing Record 42 of Set 3 | sao borja
# Processing Record 43 of Set 3 | komsomolskiy
# Processing Record 44 of Set 3 | goulburn
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | saint-louis
# Processing Record 47 of Set 3 | teya
# Processing Record 48 of Set 3 | finnsnes
# Processing Record 49 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 3 | buin
# Processing Record 1 of Set 4 | atakpame
# Processing Record 2 of Set 4 | ormos korthiou
# City not found. Skipping...
# Processing Record 3 of Set 4 | waterloo
# Processing Record 4 of Set 4 | kavaratti
# Processing Record 5 of Set 4 | khatanga
# Processing Record 6 of Set 4 | ribeira grande
# Processing Record 7 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 4 | baruun-urt
# Processing Record 9 of Set 4 | devonport
# Processing Record 10 of Set 4 | tuatapere
# Processing Record 11 of Set 4 | tirat karmel
# Processing Record 12 of Set 4 | mme
# City not found. Skipping...
# Processing Record 13 of Set 4 | bulgan
# Processing Record 14 of Set 4 | monte alegre de minas
# Processing Record 15 of Set 4 | faanui
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | guerrero negro
# Processing Record 18 of Set 4 | odweyne
# Processing Record 19 of Set 4 | caorle
# Processing Record 20 of Set 4 | natchitoches
# Processing Record 21 of Set 4 | isangel
# Processing Record 22 of Set 4 | saint-joseph
# Processing Record 23 of Set 4 | soyo
# Processing Record 24 of Set 4 | kodiak
# Processing Record 25 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 4 | ponta do sol
# Processing Record 27 of Set 4 | vestmanna
# Processing Record 28 of Set 4 | raudeberg
# Processing Record 29 of Set 4 | kingston
# Processing Record 30 of Set 4 | boralday
# Processing Record 31 of Set 4 | narsaq
# Processing Record 32 of Set 4 | constitucion
# Processing Record 33 of Set 4 | cabo san lucas
# Processing Record 34 of Set 4 | mareeba
# Processing Record 35 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 4 | clarksdale
# Processing Record 37 of Set 4 | mecca
# Processing Record 38 of Set 4 | andenes
# Processing Record 39 of Set 4 | sur
# Processing Record 40 of Set 4 | fare
# Processing Record 41 of Set 4 | totness
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | erenhot
# Processing Record 44 of Set 4 | pointe-noire
# Processing Record 45 of Set 4 | vardo
# Processing Record 46 of Set 4 | torbay
# Processing Record 47 of Set 4 | victoria
# Processing Record 48 of Set 4 | uruzgan
# Processing Record 49 of Set 4 | zhigansk
# Processing Record 50 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 5 | mahebourg
# Processing Record 2 of Set 5 | corn island
# Processing Record 3 of Set 5 | tilichiki
# Processing Record 4 of Set 5 | mar del plata
# Processing Record 5 of Set 5 | oktyabrskoye
# Processing Record 6 of Set 5 | waidhofen
# Processing Record 7 of Set 5 | bandarbeyla
# Processing Record 8 of Set 5 | presidencia roque saenz pena
# Processing Record 9 of Set 5 | marechal candido rondon
# Processing Record 10 of Set 5 | ormoz
# Processing Record 11 of Set 5 | rafai
# Processing Record 12 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 5 | acapulco
# Processing Record 14 of Set 5 | flin flon
# Processing Record 15 of Set 5 | tomatlan
# Processing Record 16 of Set 5 | bathsheba
# Processing Record 17 of Set 5 | kogon
# Processing Record 18 of Set 5 | hay river
# Processing Record 19 of Set 5 | northam
# Processing Record 20 of Set 5 | bundaberg
# Processing Record 21 of Set 5 | gulu
# Processing Record 22 of Set 5 | cagli
# Processing Record 23 of Set 5 | paramonga
# Processing Record 24 of Set 5 | tessalit
# Processing Record 25 of Set 5 | college
# Processing Record 26 of Set 5 | vila franca do campo
# Processing Record 27 of Set 5 | nishihara
# Processing Record 28 of Set 5 | pacifica
# Processing Record 29 of Set 5 | develi
# Processing Record 30 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 5 | lerwick
# Processing Record 32 of Set 5 | arroyo
# Processing Record 33 of Set 5 | gubkinskiy
# Processing Record 34 of Set 5 | jumla
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | havoysund
# Processing Record 37 of Set 5 | clayton
# Processing Record 38 of Set 5 | bairiki
# Processing Record 39 of Set 5 | lincoln
# Processing Record 40 of Set 5 | panaba
# Processing Record 41 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 5 | talnakh
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | barroquinha
# Processing Record 45 of Set 5 | dharchula
# Processing Record 46 of Set 5 | east london
# Processing Record 47 of Set 5 | longyearbyen
# Processing Record 48 of Set 5 | bubaque
# Processing Record 49 of Set 5 | nova olimpia
# Processing Record 50 of Set 5 | saint anthony
# Processing Record 1 of Set 6 | pemba
# Processing Record 2 of Set 6 | sarangani
# Processing Record 3 of Set 6 | saint george
# Processing Record 4 of Set 6 | marawi
# Processing Record 5 of Set 6 | egvekinot
# Processing Record 6 of Set 6 | sasina
# Processing Record 7 of Set 6 | yar-sale
# Processing Record 8 of Set 6 | beira
# Processing Record 9 of Set 6 | neuquen
# Processing Record 10 of Set 6 | saint-pierre
# Processing Record 11 of Set 6 | san vicente
# Processing Record 12 of Set 6 | buta
# Processing Record 13 of Set 6 | karratha
# Processing Record 14 of Set 6 | baracoa
# Processing Record 15 of Set 6 | itarema
# Processing Record 16 of Set 6 | fort nelson
# Processing Record 17 of Set 6 | codrington
# Processing Record 18 of Set 6 | chuy
# Processing Record 19 of Set 6 | takoradi
# Processing Record 20 of Set 6 | asau
# Processing Record 21 of Set 6 | peruibe
# Processing Record 22 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 6 | chapais
# Processing Record 24 of Set 6 | roros
# Processing Record 25 of Set 6 | chernyshevskiy
# Processing Record 26 of Set 6 | chicama
# Processing Record 27 of Set 6 | henties bay
# Processing Record 28 of Set 6 | yerbogachen
# Processing Record 29 of Set 6 | alyangula
# Processing Record 30 of Set 6 | urumqi
# Processing Record 31 of Set 6 | svetlaya
# Processing Record 32 of Set 6 | rio grande
# Processing Record 33 of Set 6 | severnyy
# Processing Record 34 of Set 6 | broome
# Processing Record 35 of Set 6 | ostrovnoy
# Processing Record 36 of Set 6 | mwense
# Processing Record 37 of Set 6 | cogoleto
# Processing Record 38 of Set 6 | tual
# Processing Record 39 of Set 6 | fort frances
# Processing Record 40 of Set 6 | puerto maldonado
# Processing Record 41 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 6 | laguna
# Processing Record 43 of Set 6 | christchurch
# Processing Record 44 of Set 6 | kushima
# Processing Record 45 of Set 6 | cayenne
# Processing Record 46 of Set 6 | severo-yeniseyskiy
# Processing Record 47 of Set 6 | port hardy
# Processing Record 48 of Set 6 | aksha
# Processing Record 49 of Set 6 | le port
# Processing Record 50 of Set 6 | jerome
# Processing Record 1 of Set 7 | hamilton
# Processing Record 2 of Set 7 | avera
# Processing Record 3 of Set 7 | riyadh
# Processing Record 4 of Set 7 | oloron-sainte-marie
# Processing Record 5 of Set 7 | seoul
# Processing Record 6 of Set 7 | mozarlandia
# Processing Record 7 of Set 7 | mandalgovi
# Processing Record 8 of Set 7 | pradopolis
# Processing Record 9 of Set 7 | hambantota
# Processing Record 10 of Set 7 | inza
# Processing Record 11 of Set 7 | dukat
# Processing Record 12 of Set 7 | sao geraldo do araguaia
# Processing Record 13 of Set 7 | itoman
# Processing Record 14 of Set 7 | mahanoro
# Processing Record 15 of Set 7 | nieuwpoort
# Processing Record 16 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 7 | north bend
# Processing Record 18 of Set 7 | aykhal
# Processing Record 19 of Set 7 | honningsvag
# Processing Record 20 of Set 7 | paramaribo
# Processing Record 21 of Set 7 | ravar
# Processing Record 22 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 7 | tocache
# Processing Record 24 of Set 7 | korla
# Processing Record 25 of Set 7 | saint-georges
# Processing Record 26 of Set 7 | ulaangom
# Processing Record 27 of Set 7 | albuquerque
# Processing Record 28 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 7 | havelock
# Processing Record 30 of Set 7 | praia
# Processing Record 31 of Set 7 | flinders
# Processing Record 32 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 7 | leningradskiy
# Processing Record 34 of Set 7 | mogadishu
# Processing Record 35 of Set 7 | noumea
# Processing Record 36 of Set 7 | yabrud
# Processing Record 37 of Set 7 | pakxan
# Processing Record 38 of Set 7 | ahipara
# Processing Record 39 of Set 7 | sorong
# Processing Record 40 of Set 7 | gornopravdinsk
# Processing Record 41 of Set 7 | puerto escondido
# Processing Record 42 of Set 7 | isabela
# Processing Record 43 of Set 7 | brunswick
# Processing Record 44 of Set 7 | nantucket
# Processing Record 45 of Set 7 | vostok
# Processing Record 46 of Set 7 | bartica
# Processing Record 47 of Set 7 | olafsvik
# Processing Record 48 of Set 7 | filimonovo
# Processing Record 49 of Set 7 | hvide sande
# Processing Record 50 of Set 7 | yumaguzino
# Processing Record 1 of Set 8 | udachnyy
# Processing Record 2 of Set 8 | gat
# Processing Record 3 of Set 8 | cockburn town
# Processing Record 4 of Set 8 | lidkoping
# Processing Record 5 of Set 8 | shar
# Processing Record 6 of Set 8 | japura
# Processing Record 7 of Set 8 | qianan
# Processing Record 8 of Set 8 | camocim
# Processing Record 9 of Set 8 | ilulissat
# Processing Record 10 of Set 8 | poum
# Processing Record 11 of Set 8 | zaozhuang
# Processing Record 12 of Set 8 | coralville
# Processing Record 13 of Set 8 | cidreira
# Processing Record 14 of Set 8 | khabary
# Processing Record 15 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 8 | astorga
# Processing Record 17 of Set 8 | bereda
# Processing Record 18 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 8 | half moon bay
# Processing Record 20 of Set 8 | zaozerne
# Processing Record 21 of Set 8 | somerset
# Processing Record 22 of Set 8 | jardim
# Processing Record 23 of Set 8 | cortez
# Processing Record 24 of Set 8 | san rafael del sur
# Processing Record 25 of Set 8 | sinnamary
# Processing Record 26 of Set 8 | komsomolets
# Processing Record 27 of Set 8 | lom sak
# Processing Record 28 of Set 8 | maarianhamina
# Processing Record 29 of Set 8 | miramar
# Processing Record 30 of Set 8 | miles city
# Processing Record 31 of Set 8 | dudinka
# Processing Record 32 of Set 8 | anloga
# Processing Record 33 of Set 8 | cayeli
# Processing Record 34 of Set 8 | vilhena
# Processing Record 35 of Set 8 | maniitsoq
# Processing Record 36 of Set 8 | micheweni
# Processing Record 37 of Set 8 | batagay
# Processing Record 38 of Set 8 | nador
# Processing Record 39 of Set 8 | coromandel
# Processing Record 40 of Set 8 | alice town
# Processing Record 41 of Set 8 | marsh harbour
# Processing Record 42 of Set 8 | ettaiyapuram
# Processing Record 43 of Set 8 | la brea
# Processing Record 44 of Set 8 | honiara
# Processing Record 45 of Set 8 | souillac
# Processing Record 46 of Set 8 | charleston
# Processing Record 47 of Set 8 | fairbanks
# Processing Record 48 of Set 8 | provideniya
# Processing Record 49 of Set 8 | iqaluit
# Processing Record 50 of Set 8 | bressuire
# Processing Record 1 of Set 9 | cochrane
# Processing Record 2 of Set 9 | morondava
# Processing Record 3 of Set 9 | nahrin
# Processing Record 4 of Set 9 | amga
# Processing Record 5 of Set 9 | sungairaya
# Processing Record 6 of Set 9 | pevek
# Processing Record 7 of Set 9 | rohru
# Processing Record 8 of Set 9 | anadyr
# Processing Record 9 of Set 9 | mpika
# Processing Record 10 of Set 9 | vestmannaeyjar
# Processing Record 11 of Set 9 | sabla
# Processing Record 12 of Set 9 | ghanzi
# Processing Record 13 of Set 9 | marsa matruh
# Processing Record 14 of Set 9 | baykit
# Processing Record 15 of Set 9 | puerto narino
# Processing Record 16 of Set 9 | punta cardon
# Processing Record 17 of Set 9 | waitati
# Processing Record 18 of Set 9 | manta
# Processing Record 19 of Set 9 | cervo
# Processing Record 20 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 21 of Set 9 | gobabis
# Processing Record 22 of Set 9 | tongren
# Processing Record 23 of Set 9 | kisangani
# Processing Record 24 of Set 9 | portoferraio
# Processing Record 25 of Set 9 | rauma
# Processing Record 26 of Set 9 | kaliua
# Processing Record 27 of Set 9 | santa maria
# Processing Record 28 of Set 9 | mwingi
# Processing Record 29 of Set 9 | tautira
# Processing Record 30 of Set 9 | maceio
# Processing Record 31 of Set 9 | byron bay
# Processing Record 32 of Set 9 | peleduy
# Processing Record 33 of Set 9 | ghioroc
# Processing Record 34 of Set 9 | hornepayne
# Processing Record 35 of Set 9 | sao filipe
# Processing Record 36 of Set 9 | road town
# Processing Record 37 of Set 9 | kaitong
# Processing Record 38 of Set 9 | sunamganj
# City not found. Skipping...
# Processing Record 39 of Set 9 | clyde river
# Processing Record 40 of Set 9 | comodoro rivadavia
# Processing Record 41 of Set 9 | saldanha
# Processing Record 42 of Set 9 | hami
# Processing Record 43 of Set 9 | namatanai
# Processing Record 44 of Set 9 | beloha
# Processing Record 45 of Set 9 | bam
# Processing Record 46 of Set 9 | venado tuerto
# Processing Record 47 of Set 9 | tymovskoye
# Processing Record 48 of Set 9 | rincon
# Processing Record 49 of Set 9 | ritchie
# Processing Record 50 of Set 9 | qui nhon
# Processing Record 1 of Set 10 | bara
# Processing Record 2 of Set 10 | cozumel
# Processing Record 3 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 4 of Set 10 | labuhan
# Processing Record 5 of Set 10 | geraldton
# Processing Record 6 of Set 10 | hovd
# Processing Record 7 of Set 10 | vallenar
# Processing Record 8 of Set 10 | mirabad
# Processing Record 9 of Set 10 | beringovskiy
# Processing Record 10 of Set 10 | hualmay
# Processing Record 11 of Set 10 | knokke-heist
# Processing Record 12 of Set 10 | kitimat
# Processing Record 13 of Set 10 | klaksvik
# Processing Record 14 of Set 10 | chunian
# Processing Record 15 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 10 | masallatah
# Processing Record 17 of Set 10 | dingle
# Processing Record 18 of Set 10 | kiama
# Processing Record 19 of Set 10 | san patricio
# Processing Record 20 of Set 10 | bali chak
# Processing Record 21 of Set 10 | husavik
# Processing Record 22 of Set 10 | camacupa
# Processing Record 23 of Set 10 | emerald
# Processing Record 24 of Set 10 | eureka
# Processing Record 25 of Set 10 | muroto
# Processing Record 26 of Set 10 | port-gentil
# Processing Record 27 of Set 10 | ballina
# Processing Record 28 of Set 10 | tarakan
# Processing Record 29 of Set 10 | manono
# Processing Record 30 of Set 10 | rabat
# Processing Record 31 of Set 10 | evensk
# Processing Record 32 of Set 10 | wasilla
# Processing Record 33 of Set 10 | cape canaveral
# Processing Record 34 of Set 10 | nocupetaro
# Processing Record 35 of Set 10 | newtonmore
# Processing Record 36 of Set 10 | lata
# Processing Record 37 of Set 10 | nuuk
# Processing Record 38 of Set 10 | kabanjahe
# Processing Record 39 of Set 10 | buraydah
# Processing Record 40 of Set 10 | makakilo city
# Processing Record 41 of Set 10 | askino
# Processing Record 42 of Set 10 | tiksi
# Processing Record 43 of Set 10 | namibe
# Processing Record 44 of Set 10 | uralets
# Processing Record 45 of Set 10 | opuwo
# Processing Record 46 of Set 10 | oranjemund
# Processing Record 47 of Set 10 | vao
# Processing Record 48 of Set 10 | yerofey pavlovich
# Processing Record 49 of Set 10 | weirton
# Processing Record 50 of Set 10 | bahir dar
# Processing Record 1 of Set 11 | fortuna
# Processing Record 2 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 3 of Set 11 | sexsmith
# Processing Record 4 of Set 11 | matadi
# Processing Record 5 of Set 11 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 6 of Set 11 | madinat sittah uktubar
# Processing Record 7 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 11 | adrar
# Processing Record 9 of Set 11 | rio gallegos
# Processing Record 10 of Set 11 | port arthur
# Processing Record 11 of Set 11 | kiunga
# Processing Record 12 of Set 11 | kamen-rybolov
# Processing Record 13 of Set 11 | batticaloa
# Processing Record 14 of Set 11 | port blair
# Processing Record 15 of Set 11 | swift current
# Processing Record 16 of Set 11 | terra santa
# Processing Record 17 of Set 11 | arkhara
# Processing Record 18 of Set 11 | kytmanovo
# Processing Record 19 of Set 11 | nago
# Processing Record 20 of Set 11 | pangody
# Processing Record 21 of Set 11 | linhares
# Processing Record 22 of Set 11 | broken hill
# Processing Record 23 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 24 of Set 11 | pajapan
# Processing Record 25 of Set 11 | santa isabel
# Processing Record 26 of Set 11 | pietermaritzburg
# Processing Record 27 of Set 11 | gangtok
# Processing Record 28 of Set 11 | murdochville
# Processing Record 29 of Set 11 | tromso
# Processing Record 30 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 11 | kalulushi
# Processing Record 32 of Set 11 | port augusta
# Processing Record 33 of Set 11 | llangefni
# Processing Record 34 of Set 11 | kieta
# Processing Record 35 of Set 11 | aquiraz
# Processing Record 36 of Set 11 | pitimbu
# Processing Record 37 of Set 11 | american canyon
# Processing Record 38 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 39 of Set 11 | sovetskiy
# Processing Record 40 of Set 11 | mazatlan
# Processing Record 41 of Set 11 | la ronge
# Processing Record 42 of Set 11 | lovington
# Processing Record 43 of Set 11 | boyolangu
# Processing Record 44 of Set 11 | quatre cocos
# Processing Record 45 of Set 11 | hede
# Processing Record 46 of Set 11 | nurota
# Processing Record 47 of Set 11 | emba
# Processing Record 48 of Set 11 | kokopo
# Processing Record 49 of Set 11 | kemise
# Processing Record 50 of Set 11 | safford
# Processing Record 1 of Set 12 | atar
# Processing Record 2 of Set 12 | dyersburg
# Processing Record 3 of Set 12 | xingyi
# Processing Record 4 of Set 12 | canberra
# Processing Record 5 of Set 12 | felipe carrillo puerto
# Processing Record 6 of Set 12 | along
# Processing Record 7 of Set 12 | margate
# Processing Record 8 of Set 12 | dalbandin
# Processing Record 9 of Set 12 | saverne
# Processing Record 10 of Set 12 | wadi musa
# Processing Record 11 of Set 12 | alta
# Processing Record 12 of Set 12 | batagay-alyta
# Processing Record 13 of Set 12 | mocuba
# Processing Record 14 of Set 12 | warner robins
# Processing Record 15 of Set 12 | jibuti
# Processing Record 16 of Set 12 | kupang
# Processing Record 17 of Set 12 | kendari
# Processing Record 18 of Set 12 | kautokeino
# Processing Record 19 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 20 of Set 12 | wattegama
# Processing Record 21 of Set 12 | grand gaube
# Processing Record 22 of Set 12 | simpang empat
# Processing Record 23 of Set 12 | biltine
# Processing Record 24 of Set 12 | jalu
# Processing Record 25 of Set 12 | bonavista
# Processing Record 26 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 12 | jiaozuo
# Processing Record 28 of Set 12 | linxia
# Processing Record 29 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 12 | kommunisticheskiy
# Processing Record 31 of Set 12 | kloulklubed
# Processing Record 32 of Set 12 | cabra
# Processing Record 33 of Set 12 | hirara
# Processing Record 34 of Set 12 | bestobe
# Processing Record 35 of Set 12 | swidnica
# Processing Record 36 of Set 12 | oktyabrskiy
# Processing Record 37 of Set 12 | padang
# Processing Record 38 of Set 12 | marstal
# Processing Record 39 of Set 12 | taree
# Processing Record 40 of Set 12 | kununurra
# Processing Record 41 of Set 12 | lipari
# Processing Record 42 of Set 12 | bonfim
# Processing Record 43 of Set 12 | vidim
# Processing Record 44 of Set 12 | zaranj
# Processing Record 45 of Set 12 | mangaratiba
# Processing Record 46 of Set 12 | mabaruma
# Processing Record 47 of Set 12 | grand-lahou
# Processing Record 48 of Set 12 | okhotsk
# Processing Record 49 of Set 12 | sivaki
# Processing Record 50 of Set 12 | pangnirtung
# Processing Record 1 of Set 13 | grindavik
# Processing Record 2 of Set 13 | altay
# Processing Record 3 of Set 13 | boca do acre
# Processing Record 4 of Set 13 | port antonio
# Processing Record 5 of Set 13 | pak chong
# Processing Record 6 of Set 13 | frederico westphalen
# Processing Record 7 of Set 13 | san buenaventura
# Processing Record 8 of Set 13 | berbera
# Processing Record 9 of Set 13 | oudtshoorn
# Processing Record 10 of Set 13 | wyndham
# Processing Record 11 of Set 13 | goundam
# Processing Record 12 of Set 13 | sembe
# Processing Record 13 of Set 13 | skeldon
# Processing Record 14 of Set 13 | touros
# Processing Record 15 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 16 of Set 13 | kargil
# Processing Record 17 of Set 13 | nelson bay
# Processing Record 18 of Set 13 | lavrentiya
# Processing Record 19 of Set 13 | amapa
# Processing Record 20 of Set 13 | manokwari
# Processing Record 21 of Set 13 | remanso
# Processing Record 22 of Set 13 | duki
# Processing Record 23 of Set 13 | paso de los toros
# Processing Record 24 of Set 13 | bilma
# Processing Record 25 of Set 13 | huaihua
# Processing Record 26 of Set 13 | maues
# Processing Record 27 of Set 13 | palmer
# Processing Record 28 of Set 13 | khor
# Processing Record 29 of Set 13 | langsa
# Processing Record 30 of Set 13 | mizdah
# Processing Record 31 of Set 13 | telimele
# Processing Record 32 of Set 13 | sarahan
# Processing Record 33 of Set 13 | hervey bay
# Processing Record 34 of Set 13 | gualaquiza
# Processing Record 35 of Set 13 | meulaboh
# Processing Record 36 of Set 13 | lewistown
# Processing Record 37 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 13 | shishou
# Processing Record 39 of Set 13 | hobyo
# Processing Record 40 of Set 13 | estelle
# Processing Record 41 of Set 13 | araguaina
# Processing Record 42 of Set 13 | san cristobal
# Processing Record 43 of Set 13 | palmares do sul
# Processing Record 44 of Set 13 | tigil
# Processing Record 45 of Set 13 | lishan
# Processing Record 46 of Set 13 | mishelevka
# Processing Record 47 of Set 13 | lakes entrance
# Processing Record 48 of Set 13 | shenjiamen
# Processing Record 49 of Set 13 | merke
# Processing Record 50 of Set 13 | sorland
# Processing Record 1 of Set 14 | mnogovershinnyy
# Processing Record 2 of Set 14 | zandvoort
# Processing Record 3 of Set 14 | balaghat
# Processing Record 4 of Set 14 | deputatskiy
# Processing Record 5 of Set 14 | srikakulam
# Processing Record 6 of Set 14 | gamba
# Processing Record 7 of Set 14 | camacha
# Processing Record 8 of Set 14 | sittingbourne
# Processing Record 9 of Set 14 | wilmington
# Processing Record 10 of Set 14 | turukhansk
# Processing Record 11 of Set 14 | homer
# Processing Record 12 of Set 14 | mount gambier
# Processing Record 13 of Set 14 | basco
# Processing Record 14 of Set 14 | mezen
# Processing Record 15 of Set 14 | tambilil
# Processing Record 16 of Set 14 | ilinskiy
# Processing Record 17 of Set 14 | langenburg
# Processing Record 18 of Set 14 | smithers
# Processing Record 19 of Set 14 | huarmey
# Processing Record 20 of Set 14 | kahului
# Processing Record 21 of Set 14 | aklavik
# Processing Record 22 of Set 14 | venice
# Processing Record 23 of Set 14 | ust-kuyga
# Processing Record 24 of Set 14 | xucheng
# Processing Record 25 of Set 14 | molina
# Processing Record 26 of Set 14 | sola
# Processing Record 27 of Set 14 | malpe
# Processing Record 28 of Set 14 | cairns
# Processing Record 29 of Set 14 | los llanos de aridane
# Processing Record 30 of Set 14 | dublin
# Processing Record 31 of Set 14 | kushiro
# Processing Record 32 of Set 14 | inveraray
# City not found. Skipping...
# Processing Record 33 of Set 14 | zvenigovo
# Processing Record 34 of Set 14 | palmas bellas
# Processing Record 35 of Set 14 | pedernales
# Processing Record 36 of Set 14 | san borja
# Processing Record 37 of Set 14 | muli
# Processing Record 38 of Set 14 | riviere-au-renard
# Processing Record 39 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 40 of Set 14 | kaeo
# Processing Record 41 of Set 14 | tevaitoa
# Processing Record 42 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 14 | khandbari
# Processing Record 44 of Set 14 | shakhtinsk
# Processing Record 45 of Set 14 | lorengau
# Processing Record 46 of Set 14 | skagen
# Processing Record 47 of Set 14 | kemijarvi
# Processing Record 48 of Set 14 | mangan
# Processing Record 49 of Set 14 | bridgton
# Processing Record 50 of Set 14 | sao joao da barra
# Processing Record 1 of Set 15 | colombo
# Processing Record 2 of Set 15 | ola
# Processing Record 3 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 15 | coquimbo
# Processing Record 5 of Set 15 | kyren
# Processing Record 6 of Set 15 | wageningen
# Processing Record 7 of Set 15 | alvinopolis
# Processing Record 8 of Set 15 | dolores
# Processing Record 9 of Set 15 | lucapa
# Processing Record 10 of Set 15 | suntar
# Processing Record 11 of Set 15 | farah
# Processing Record 12 of Set 15 | high prairie
# Processing Record 13 of Set 15 | caibarien
# Processing Record 14 of Set 15 | muzhi
# Processing Record 15 of Set 15 | mamontovo
# Processing Record 16 of Set 15 | dana point
# Processing Record 17 of Set 15 | zitsa
# Processing Record 18 of Set 15 | elbistan
# Processing Record 19 of Set 15 | jinchang
# Processing Record 20 of Set 15 | hangu
# Processing Record 21 of Set 15 | hasaki
# Processing Record 22 of Set 15 | shouguang
# Processing Record 23 of Set 15 | fayaoue
# Processing Record 24 of Set 15 | kologriv
# Processing Record 25 of Set 15 | ixtapa
# Processing Record 26 of Set 15 | nalgonda
# Processing Record 27 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 15 | kuznechnoye
# Processing Record 29 of Set 15 | shingu
# Processing Record 30 of Set 15 | yumen
# Processing Record 31 of Set 15 | golyshmanovo
# Processing Record 32 of Set 15 | abu samrah
# Processing Record 33 of Set 15 | royan
# Processing Record 34 of Set 15 | tateyama
# Processing Record 35 of Set 15 | guaymas
# Processing Record 36 of Set 15 | san quintin
# Processing Record 37 of Set 15 | panalingaan
# Processing Record 38 of Set 15 | pochutla
# Processing Record 39 of Set 15 | nome
# Processing Record 40 of Set 15 | sambava
# Processing Record 41 of Set 15 | katsuura
# Processing Record 42 of Set 15 | yokadouma
# Processing Record 43 of Set 15 | ossora
# Processing Record 44 of Set 15 | nhulunbuy
# Processing Record 45 of Set 15 | eyl
# Processing Record 46 of Set 15 | isla vista
# Processing Record 47 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 48 of Set 15 | thilogne
# City not found. Skipping...
# Processing Record 49 of Set 15 | harer
# Processing Record 50 of Set 15 | omsukchan
# Processing Record 1 of Set 16 | abatskoye
# Processing Record 2 of Set 16 | shiyan
# Processing Record 3 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 16 | san policarpo
# Processing Record 5 of Set 16 | pirajui
# Processing Record 6 of Set 16 | zhanaozen
# Processing Record 7 of Set 16 | inuvik
# Processing Record 8 of Set 16 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 16 | uniao
# Processing Record 10 of Set 16 | kidal
# Processing Record 11 of Set 16 | katherine
# Processing Record 12 of Set 16 | lujan
# Processing Record 13 of Set 16 | yukamenskoye
# Processing Record 14 of Set 16 | skagastrond
# City not found. Skipping...
# Processing Record 15 of Set 16 | gaoua
# Processing Record 16 of Set 16 | talcahuano
# Processing Record 17 of Set 16 | samana
# Processing Record 18 of Set 16 | ust-tsilma
# Processing Record 19 of Set 16 | pospelikha
# Processing Record 20 of Set 16 | ratnagiri
# Processing Record 21 of Set 16 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 16 | rostovka
# Processing Record 23 of Set 16 | bridlington
# Processing Record 24 of Set 16 | vila velha
# Processing Record 25 of Set 16 | datong
# Processing Record 26 of Set 16 | dillon
# Processing Record 27 of Set 16 | stamsund
# City not found. Skipping...
# Processing Record 28 of Set 16 | rocha
# Processing Record 29 of Set 16 | gilgit
# Processing Record 30 of Set 16 | mehamn
# Processing Record 31 of Set 16 | reconquista
# Processing Record 32 of Set 16 | mercedes
# Processing Record 33 of Set 16 | santa ana
# Processing Record 34 of Set 16 | kedrovyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 728

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Airai  -8.9266  125.4092     60.73       100         100
# 1      Sunndalsora  62.6754    8.5515     23.00        54           0
# 2        Carnarvon -24.8667  113.6333     75.20       100          40
# 3  Haines Junction  60.7522 -137.5108    -16.60        52          16
# 4           Albany  42.6001  -73.9662     30.99        72         100
# 5            Bluff -46.6000  168.3333     58.26        73          97
# 6           Castro -24.7911  -50.0119     70.72        67           0
# 7        La Romana  18.4273  -68.9728     82.40        65          40
# 8          Naqadeh  36.9553   45.3880     39.47        72           0
# 9          Chifeng  42.2683  118.9636      2.30        85           0
#
#    Wind Speed Country Current Description
# 0        2.62      TL     overcast clouds
# 1        5.75      NO           clear sky
# 2       10.36      AU    scattered clouds
# 3        1.14      CA          few clouds
# 4        3.36      US          light snow
# 5        5.21      NZ          light rain
# 6        4.92      BR           clear sky
# 7        9.22      DO    scattered clouds
# 8        4.23      IR           clear sky
# 9        5.48      CN           clear sky

# %%
# Reorder the columns 
new_column_city_data=['City','Country','Lat','Lng','Max Temp', 'Humidity', 'Cloudiness','Wind Speed', 'Current Description']

# %%
city_data_df = city_data_df[new_column_city_data]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Airai      TL  -8.9266  125.4092     60.73       100         100
# 1      Sunndalsora      NO  62.6754    8.5515     23.00        54           0
# 2        Carnarvon      AU -24.8667  113.6333     75.20       100          40
# 3  Haines Junction      CA  60.7522 -137.5108    -16.60        52          16
# 4           Albany      US  42.6001  -73.9662     30.99        72         100
# 5            Bluff      NZ -46.6000  168.3333     58.26        73          97
# 6           Castro      BR -24.7911  -50.0119     70.72        67           0
# 7        La Romana      DO  18.4273  -68.9728     82.40        65          40
# 8          Naqadeh      IR  36.9553   45.3880     39.47        72           0
# 9          Chifeng      CN  42.2683  118.9636      2.30        85           0
#
#    Wind Speed Current Description
# 0        2.62     overcast clouds
# 1        5.75           clear sky
# 2       10.36    scattered clouds
# 3        1.14          few clouds
# 4        3.36          light snow
# 5        5.21          light rain
# 6        4.92           clear sky
# 7        9.22    scattered clouds
# 8        4.23           clear sky
# 9        5.48           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

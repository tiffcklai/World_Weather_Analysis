# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b0892e6d6a5ef8838277813d2bd34fb2

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | kirakira
# Processing Record 5 of Set 1 | pulsano
# Processing Record 6 of Set 1 | mercedes
# Processing Record 7 of Set 1 | chaupimarca
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | uglegorsk
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | pangnirtung
# Processing Record 14 of Set 1 | golden
# Processing Record 15 of Set 1 | chippewa falls
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 1 | cidreira
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | huamachuco
# Processing Record 24 of Set 1 | bengkulu
# Processing Record 25 of Set 1 | meulaboh
# Processing Record 26 of Set 1 | broome
# Processing Record 27 of Set 1 | ostrovnoy
# Processing Record 28 of Set 1 | cayenne
# Processing Record 29 of Set 1 | suhbaatar
# Processing Record 30 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | port lincoln
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | damietta
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | sisimiut
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | tutoia
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | sao gabriel da cachoeira
# Processing Record 46 of Set 1 | pathein
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | puerto baquerizo moreno
# Processing Record 49 of Set 1 | kamenka
# Processing Record 50 of Set 1 | kavieng
# Processing Record 1 of Set 2 | aswan
# Processing Record 2 of Set 2 | wanaka
# Processing Record 3 of Set 2 | kdyne
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | kuah
# Processing Record 6 of Set 2 | port hardy
# Processing Record 7 of Set 2 | kalianget
# Processing Record 8 of Set 2 | riviere-au-renard
# Processing Record 9 of Set 2 | half moon bay
# Processing Record 10 of Set 2 | whitehorse
# Processing Record 11 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 12 of Set 2 | hami
# Processing Record 13 of Set 2 | saint george
# Processing Record 14 of Set 2 | morehead
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | tuatapere
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | comodoro rivadavia
# Processing Record 21 of Set 2 | jalu
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | ponta do sol
# Processing Record 24 of Set 2 | sao jose da coroa grande
# Processing Record 25 of Set 2 | vardo
# Processing Record 26 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 27 of Set 2 | salinopolis
# Processing Record 28 of Set 2 | torbay
# Processing Record 29 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 2 | ivaipora
# Processing Record 31 of Set 2 | nantucket
# Processing Record 32 of Set 2 | muros
# Processing Record 33 of Set 2 | raigarh
# Processing Record 34 of Set 2 | severo-kurilsk
# Processing Record 35 of Set 2 | lompoc
# Processing Record 36 of Set 2 | fortuna
# Processing Record 37 of Set 2 | caetite
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | victoria
# Processing Record 40 of Set 2 | bahia honda
# Processing Record 41 of Set 2 | tahoua
# Processing Record 42 of Set 2 | evensk
# Processing Record 43 of Set 2 | bilma
# Processing Record 44 of Set 2 | vyazemskiy
# Processing Record 45 of Set 2 | marsa matruh
# Processing Record 46 of Set 2 | talnakh
# Processing Record 47 of Set 2 | stromness
# Processing Record 48 of Set 2 | margate
# Processing Record 49 of Set 2 | port blair
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | chapais
# Processing Record 3 of Set 3 | shitkino
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | havoysund
# Processing Record 6 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 3 | kruisfontein
# Processing Record 8 of Set 3 | kawalu
# Processing Record 9 of Set 3 | vanimo
# Processing Record 10 of Set 3 | dawlatabad
# Processing Record 11 of Set 3 | kautokeino
# Processing Record 12 of Set 3 | krumovgrad
# Processing Record 13 of Set 3 | viedma
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | lasa
# Processing Record 16 of Set 3 | namatanai
# Processing Record 17 of Set 3 | semey
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | kahului
# Processing Record 20 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | mildura
# Processing Record 23 of Set 3 | qui nhon
# Processing Record 24 of Set 3 | magistralnyy
# Processing Record 25 of Set 3 | yar-sale
# Processing Record 26 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 3 | tarauaca
# Processing Record 28 of Set 3 | nanakuli
# Processing Record 29 of Set 3 | cap malheureux
# Processing Record 30 of Set 3 | bozova
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | itarema
# Processing Record 33 of Set 3 | kapaa
# Processing Record 34 of Set 3 | villa bruzual
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | iqaluit
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | barrow
# Processing Record 39 of Set 3 | college
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 3 | les herbiers
# Processing Record 44 of Set 3 | bluff
# Processing Record 45 of Set 3 | frontera
# Processing Record 46 of Set 3 | takoradi
# Processing Record 47 of Set 3 | thunder bay
# Processing Record 48 of Set 3 | paamiut
# Processing Record 49 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 3 | fukue
# Processing Record 1 of Set 4 | cherskiy
# Processing Record 2 of Set 4 | butaritari
# Processing Record 3 of Set 4 | mitsamiouli
# Processing Record 4 of Set 4 | kalmar
# Processing Record 5 of Set 4 | tanout
# Processing Record 6 of Set 4 | shenjiamen
# Processing Record 7 of Set 4 | rawson
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | borba
# Processing Record 10 of Set 4 | charters towers
# Processing Record 11 of Set 4 | luderitz
# Processing Record 12 of Set 4 | lorengau
# Processing Record 13 of Set 4 | puyang
# Processing Record 14 of Set 4 | sao filipe
# Processing Record 15 of Set 4 | yuksekova
# Processing Record 16 of Set 4 | vaini
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | tasiilaq
# Processing Record 19 of Set 4 | villaviciosa
# Processing Record 20 of Set 4 | bermejo
# Processing Record 21 of Set 4 | verkhoyansk
# Processing Record 22 of Set 4 | henties bay
# Processing Record 23 of Set 4 | tucupita
# Processing Record 24 of Set 4 | lincoln
# Processing Record 25 of Set 4 | malynivka
# Processing Record 26 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 4 | tchibanga
# Processing Record 28 of Set 4 | ouadda
# Processing Record 29 of Set 4 | vaitape
# Processing Record 30 of Set 4 | anadyr
# Processing Record 31 of Set 4 | koutiala
# Processing Record 32 of Set 4 | nome
# Processing Record 33 of Set 4 | coffs harbour
# Processing Record 34 of Set 4 | westport
# Processing Record 35 of Set 4 | yeppoon
# Processing Record 36 of Set 4 | fatehgarh
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | ilhabela
# Processing Record 39 of Set 4 | la grande
# Processing Record 40 of Set 4 | vostok
# Processing Record 41 of Set 4 | ulaangom
# Processing Record 42 of Set 4 | lappeenranta
# Processing Record 43 of Set 4 | baruun-urt
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | athabasca
# Processing Record 46 of Set 4 | agadez
# Processing Record 47 of Set 4 | careiro da varzea
# Processing Record 48 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 49 of Set 4 | kloulklubed
# Processing Record 50 of Set 4 | port elizabeth
# Processing Record 1 of Set 5 | touros
# Processing Record 2 of Set 5 | amga
# Processing Record 3 of Set 5 | pisco
# Processing Record 4 of Set 5 | lucapa
# Processing Record 5 of Set 5 | sibu
# Processing Record 6 of Set 5 | bethel
# Processing Record 7 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 8 of Set 5 | petrozavodsk
# Processing Record 9 of Set 5 | san quintin
# Processing Record 10 of Set 5 | waw
# Processing Record 11 of Set 5 | sovetskiy
# Processing Record 12 of Set 5 | fort nelson
# Processing Record 13 of Set 5 | srednekolymsk
# Processing Record 14 of Set 5 | zhigalovo
# Processing Record 15 of Set 5 | veraval
# Processing Record 16 of Set 5 | sur
# Processing Record 17 of Set 5 | houma
# Processing Record 18 of Set 5 | leningradskiy
# Processing Record 19 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 5 | pizarro
# Processing Record 21 of Set 5 | bowen
# Processing Record 22 of Set 5 | solnechnyy
# Processing Record 23 of Set 5 | humaita
# Processing Record 24 of Set 5 | sao desiderio
# Processing Record 25 of Set 5 | kholm
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | pascagoula
# Processing Record 28 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 5 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 30 of Set 5 | vitim
# Processing Record 31 of Set 5 | ocos
# Processing Record 32 of Set 5 | kaa-khem
# Processing Record 33 of Set 5 | kodinsk
# Processing Record 34 of Set 5 | buala
# Processing Record 35 of Set 5 | umm lajj
# Processing Record 36 of Set 5 | oranjemund
# Processing Record 37 of Set 5 | nanortalik
# Processing Record 38 of Set 5 | geraldton
# Processing Record 39 of Set 5 | ruwi
# Processing Record 40 of Set 5 | pajapan
# Processing Record 41 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 5 | longyearbyen
# Processing Record 43 of Set 5 | mount gambier
# Processing Record 44 of Set 5 | norman wells
# Processing Record 45 of Set 5 | nuuk
# Processing Record 46 of Set 5 | katsuura
# Processing Record 47 of Set 5 | kariba
# Processing Record 48 of Set 5 | copiapo
# Processing Record 49 of Set 5 | lavrentiya
# Processing Record 50 of Set 5 | oyama
# Processing Record 1 of Set 6 | chokurdakh
# Processing Record 2 of Set 6 | baculin
# Processing Record 3 of Set 6 | port alfred
# Processing Record 4 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 6 | shellbrook
# Processing Record 6 of Set 6 | provideniya
# Processing Record 7 of Set 6 | monroe
# Processing Record 8 of Set 6 | atlantic city
# Processing Record 9 of Set 6 | morro bay
# Processing Record 10 of Set 6 | puerto madryn
# Processing Record 11 of Set 6 | kiruna
# Processing Record 12 of Set 6 | bambous virieux
# Processing Record 13 of Set 6 | puerto escondido
# Processing Record 14 of Set 6 | senanga
# Processing Record 15 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 16 of Set 6 | vao
# Processing Record 17 of Set 6 | brownsville
# Processing Record 18 of Set 6 | japura
# Processing Record 19 of Set 6 | beringovskiy
# Processing Record 20 of Set 6 | puksoozero
# Processing Record 21 of Set 6 | qaqortoq
# Processing Record 22 of Set 6 | zhuhai
# Processing Record 23 of Set 6 | teguldet
# Processing Record 24 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 6 | misratah
# Processing Record 26 of Set 6 | airai
# Processing Record 27 of Set 6 | cockburn town
# Processing Record 28 of Set 6 | samarai
# Processing Record 29 of Set 6 | shingu
# Processing Record 30 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 31 of Set 6 | pimentel
# Processing Record 32 of Set 6 | acarau
# Processing Record 33 of Set 6 | hofn
# Processing Record 34 of Set 6 | agua dulce
# Processing Record 35 of Set 6 | quthing
# Processing Record 36 of Set 6 | madimba
# Processing Record 37 of Set 6 | hasaki
# Processing Record 38 of Set 6 | camacupa
# Processing Record 39 of Set 6 | ahipara
# Processing Record 40 of Set 6 | lufilufi
# Processing Record 41 of Set 6 | ancud
# Processing Record 42 of Set 6 | borovoy
# Processing Record 43 of Set 6 | yulara
# Processing Record 44 of Set 6 | turukhansk
# Processing Record 45 of Set 6 | nerchinskiy zavod
# Processing Record 46 of Set 6 | mackenzie
# Processing Record 47 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 6 | khatanga
# Processing Record 49 of Set 6 | san vicente
# Processing Record 50 of Set 6 | kayerkan
# Processing Record 1 of Set 7 | marawi
# Processing Record 2 of Set 7 | khao yoi
# Processing Record 3 of Set 7 | antofagasta
# Processing Record 4 of Set 7 | maniitsoq
# Processing Record 5 of Set 7 | cervo
# Processing Record 6 of Set 7 | lima
# Processing Record 7 of Set 7 | sangod
# Processing Record 8 of Set 7 | vila velha
# Processing Record 9 of Set 7 | bathsheba
# Processing Record 10 of Set 7 | andenes
# Processing Record 11 of Set 7 | asifabad
# Processing Record 12 of Set 7 | binzhou
# Processing Record 13 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 7 | san patricio
# Processing Record 16 of Set 7 | vaxjo
# Processing Record 17 of Set 7 | chilca
# Processing Record 18 of Set 7 | leshukonskoye
# Processing Record 19 of Set 7 | thinadhoo
# Processing Record 20 of Set 7 | qazvin
# Processing Record 21 of Set 7 | tres picos
# Processing Record 22 of Set 7 | brasilia de minas
# Processing Record 23 of Set 7 | bahia blanca
# Processing Record 24 of Set 7 | khovu-aksy
# Processing Record 25 of Set 7 | hambantota
# Processing Record 26 of Set 7 | dunedin
# Processing Record 27 of Set 7 | mantua
# Processing Record 28 of Set 7 | lakes entrance
# Processing Record 29 of Set 7 | bereda
# Processing Record 30 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 7 | araouane
# Processing Record 32 of Set 7 | ust-kuyga
# Processing Record 33 of Set 7 | naze
# Processing Record 34 of Set 7 | port-gentil
# Processing Record 35 of Set 7 | carnarvon
# Processing Record 36 of Set 7 | akodia
# Processing Record 37 of Set 7 | bathurst
# Processing Record 38 of Set 7 | tangi
# Processing Record 39 of Set 7 | sergach
# Processing Record 40 of Set 7 | pochutla
# Processing Record 41 of Set 7 | nelson bay
# Processing Record 42 of Set 7 | ambilobe
# Processing Record 43 of Set 7 | otradnoye
# Processing Record 44 of Set 7 | baherden
# Processing Record 45 of Set 7 | townsville
# Processing Record 46 of Set 7 | sitka
# Processing Record 47 of Set 7 | umm kaddadah
# Processing Record 48 of Set 7 | sinegorye
# Processing Record 49 of Set 7 | luis correia
# Processing Record 50 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 8 | cabra
# Processing Record 2 of Set 8 | caiaponia
# Processing Record 3 of Set 8 | hamada
# Processing Record 4 of Set 8 | ranong
# Processing Record 5 of Set 8 | horsham
# Processing Record 6 of Set 8 | tateyama
# Processing Record 7 of Set 8 | ye
# City not found. Skipping...
# Processing Record 8 of Set 8 | komsomolskiy
# Processing Record 9 of Set 8 | nikki
# Processing Record 10 of Set 8 | baker city
# Processing Record 11 of Set 8 | yenagoa
# Processing Record 12 of Set 8 | volga
# Processing Record 13 of Set 8 | tabou
# Processing Record 14 of Set 8 | chumphon
# Processing Record 15 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 16 of Set 8 | san cristobal
# Processing Record 17 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 8 | mpongwe
# Processing Record 19 of Set 8 | arlit
# Processing Record 20 of Set 8 | andover
# Processing Record 21 of Set 8 | yvetot
# Processing Record 22 of Set 8 | atar
# Processing Record 23 of Set 8 | williston
# Processing Record 24 of Set 8 | havre-saint-pierre
# Processing Record 25 of Set 8 | sapao
# City not found. Skipping...
# Processing Record 26 of Set 8 | khambhat
# Processing Record 27 of Set 8 | noumea
# Processing Record 28 of Set 8 | carutapera
# Processing Record 29 of Set 8 | cabo san lucas
# Processing Record 30 of Set 8 | nioro
# Processing Record 31 of Set 8 | stod
# Processing Record 32 of Set 8 | olafsvik
# Processing Record 33 of Set 8 | skjervoy
# Processing Record 34 of Set 8 | kupang
# Processing Record 35 of Set 8 | dubbo
# Processing Record 36 of Set 8 | gorontalo
# Processing Record 37 of Set 8 | saint-pierre
# Processing Record 38 of Set 8 | inuvik
# Processing Record 39 of Set 8 | port keats
# Processing Record 40 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 8 | helong
# Processing Record 42 of Set 8 | gold coast
# Processing Record 43 of Set 8 | neiafu
# Processing Record 44 of Set 8 | klamath falls
# Processing Record 45 of Set 8 | te anau
# Processing Record 46 of Set 8 | ifanadiana
# Processing Record 47 of Set 8 | nouadhibou
# Processing Record 48 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 8 | rocha
# Processing Record 50 of Set 8 | pringsewu
# Processing Record 1 of Set 9 | katherine
# Processing Record 2 of Set 9 | kieta
# Processing Record 3 of Set 9 | bulawayo
# Processing Record 4 of Set 9 | abu samrah
# Processing Record 5 of Set 9 | husavik
# Processing Record 6 of Set 9 | pacific grove
# Processing Record 7 of Set 9 | sadovoye
# Processing Record 8 of Set 9 | kazerun
# Processing Record 9 of Set 9 | guerrero negro
# Processing Record 10 of Set 9 | tagusao
# Processing Record 11 of Set 9 | padang
# Processing Record 12 of Set 9 | ostashkov
# Processing Record 13 of Set 9 | benguela
# Processing Record 14 of Set 9 | aklavik
# Processing Record 15 of Set 9 | magui
# City not found. Skipping...
# Processing Record 16 of Set 9 | alofi
# Processing Record 17 of Set 9 | cabedelo
# Processing Record 18 of Set 9 | pevek
# Processing Record 19 of Set 9 | saint anthony
# Processing Record 20 of Set 9 | champerico
# Processing Record 21 of Set 9 | caceres
# Processing Record 22 of Set 9 | souillac
# Processing Record 23 of Set 9 | hualmay
# Processing Record 24 of Set 9 | hovd
# Processing Record 25 of Set 9 | todos santos
# Processing Record 26 of Set 9 | malanje
# Processing Record 27 of Set 9 | angra
# City not found. Skipping...
# Processing Record 28 of Set 9 | hamilton
# Processing Record 29 of Set 9 | lotung
# City not found. Skipping...
# Processing Record 30 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 9 | lagoa
# Processing Record 32 of Set 9 | caravelas
# Processing Record 33 of Set 9 | banswara
# Processing Record 34 of Set 9 | mae hong son
# Processing Record 35 of Set 9 | verkhnevilyuysk
# Processing Record 36 of Set 9 | ixtapa
# Processing Record 37 of Set 9 | chumikan
# Processing Record 38 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 39 of Set 9 | chiredzi
# Processing Record 40 of Set 9 | nizhniy ingash
# Processing Record 41 of Set 9 | talakan
# Processing Record 42 of Set 9 | makat
# Processing Record 43 of Set 9 | matagami
# Processing Record 44 of Set 9 | karakol
# Processing Record 45 of Set 9 | labuhan
# Processing Record 46 of Set 9 | san antonio
# Processing Record 47 of Set 9 | taganak
# Processing Record 48 of Set 9 | la roda
# Processing Record 49 of Set 9 | dzaoudzi
# Processing Record 50 of Set 9 | zhigansk
# Processing Record 1 of Set 10 | guamuchil
# Processing Record 2 of Set 10 | lae
# Processing Record 3 of Set 10 | kigoma
# Processing Record 4 of Set 10 | roma
# Processing Record 5 of Set 10 | lucelia
# Processing Record 6 of Set 10 | isangel
# Processing Record 7 of Set 10 | constitucion
# Processing Record 8 of Set 10 | chengde
# Processing Record 9 of Set 10 | tunduma
# Processing Record 10 of Set 10 | saurimo
# Processing Record 11 of Set 10 | mikhaylovka
# Processing Record 12 of Set 10 | zelenogradsk
# Processing Record 13 of Set 10 | lazaro cardenas
# Processing Record 14 of Set 10 | salina cruz
# Processing Record 15 of Set 10 | sola
# Processing Record 16 of Set 10 | karratha
# Processing Record 17 of Set 10 | richards bay
# Processing Record 18 of Set 10 | bandarbeyla
# Processing Record 19 of Set 10 | tiznit
# Processing Record 20 of Set 10 | karachi
# Processing Record 21 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 10 | nanchang
# Processing Record 23 of Set 10 | morant bay
# Processing Record 24 of Set 10 | laguna
# Processing Record 25 of Set 10 | xuddur
# Processing Record 26 of Set 10 | halden
# Processing Record 27 of Set 10 | kolokani
# Processing Record 28 of Set 10 | sungaipenuh
# Processing Record 29 of Set 10 | hobyo
# Processing Record 30 of Set 10 | usogorsk
# Processing Record 31 of Set 10 | coquimbo
# Processing Record 32 of Set 10 | sarakhs
# Processing Record 33 of Set 10 | mocoa
# Processing Record 34 of Set 10 | haines junction
# Processing Record 35 of Set 10 | beaverlodge
# Processing Record 36 of Set 10 | mapiri
# Processing Record 37 of Set 10 | safaga
# Processing Record 38 of Set 10 | pokhara
# Processing Record 39 of Set 10 | sussex
# Processing Record 40 of Set 10 | ginir
# Processing Record 41 of Set 10 | lata
# Processing Record 42 of Set 10 | banyo
# Processing Record 43 of Set 10 | wladyslawowo
# Processing Record 44 of Set 10 | sao joao da barra
# Processing Record 45 of Set 10 | tocantinopolis
# City not found. Skipping...
# Processing Record 46 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 47 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 10 | dong hoi
# Processing Record 49 of Set 10 | pimenta bueno
# Processing Record 50 of Set 10 | haverfordwest
# Processing Record 1 of Set 11 | vila franca do campo
# Processing Record 2 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 11 | lac du bonnet
# Processing Record 4 of Set 11 | novopokrovka
# Processing Record 5 of Set 11 | amuntai
# Processing Record 6 of Set 11 | port macquarie
# Processing Record 7 of Set 11 | novoagansk
# Processing Record 8 of Set 11 | keetmanshoop
# Processing Record 9 of Set 11 | tura
# Processing Record 10 of Set 11 | christchurch
# Processing Record 11 of Set 11 | ulety
# Processing Record 12 of Set 11 | tanggu
# Processing Record 13 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 11 | beidao
# Processing Record 15 of Set 11 | sirjan
# Processing Record 16 of Set 11 | wahiawa
# Processing Record 17 of Set 11 | arman
# Processing Record 18 of Set 11 | izhma
# Processing Record 19 of Set 11 | koulikoro
# Processing Record 20 of Set 11 | pangody
# Processing Record 21 of Set 11 | coihaique
# Processing Record 22 of Set 11 | boddam
# Processing Record 23 of Set 11 | kaduqli
# Processing Record 24 of Set 11 | tokur
# Processing Record 25 of Set 11 | camacha
# Processing Record 26 of Set 11 | waipawa
# Processing Record 27 of Set 11 | chuy
# Processing Record 28 of Set 11 | sompeta
# Processing Record 29 of Set 11 | sergeyevka
# Processing Record 30 of Set 11 | kavaratti
# Processing Record 31 of Set 11 | seoul
# Processing Record 32 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 34 of Set 11 | xai-xai
# Processing Record 35 of Set 11 | skelleftea
# Processing Record 36 of Set 11 | sao felix do xingu
# Processing Record 37 of Set 11 | kokopo
# Processing Record 38 of Set 11 | tyumentsevo
# Processing Record 39 of Set 11 | ushtobe
# Processing Record 40 of Set 11 | poum
# Processing Record 41 of Set 11 | lapi
# Processing Record 42 of Set 11 | derzhavinsk
# Processing Record 43 of Set 11 | isiro
# Processing Record 44 of Set 11 | mancio lima
# Processing Record 45 of Set 11 | codrington
# Processing Record 46 of Set 11 | swan river
# Processing Record 47 of Set 11 | pinega
# Processing Record 48 of Set 11 | krasnoborsk
# Processing Record 49 of Set 11 | vuktyl
# Processing Record 50 of Set 11 | saint-augustin
# Processing Record 1 of Set 12 | tangjiazhuang
# Processing Record 2 of Set 12 | san carlos de bariloche
# Processing Record 3 of Set 12 | stokmarknes
# Processing Record 4 of Set 12 | grindavik
# Processing Record 5 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 12 | kebemer
# City not found. Skipping...
# Processing Record 7 of Set 12 | la rioja
# Processing Record 8 of Set 12 | faanui
# Processing Record 9 of Set 12 | berlevag
# Processing Record 10 of Set 12 | general roca
# Processing Record 11 of Set 12 | gladstone
# Processing Record 12 of Set 12 | karpushikha
# Processing Record 13 of Set 12 | kandrian
# Processing Record 14 of Set 12 | koubia
# Processing Record 15 of Set 12 | bakel
# Processing Record 16 of Set 12 | turkistan
# Processing Record 17 of Set 12 | aykhal
# Processing Record 18 of Set 12 | saint-joseph
# Processing Record 19 of Set 12 | talbahat
# Processing Record 20 of Set 12 | sale
# Processing Record 21 of Set 12 | silifke
# Processing Record 22 of Set 12 | kitimat
# Processing Record 23 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 12 | tucurui
# Processing Record 25 of Set 12 | oga
# Processing Record 26 of Set 12 | jiaocheng
# Processing Record 27 of Set 12 | bulgan
# Processing Record 28 of Set 12 | la ronge
# Processing Record 29 of Set 12 | port moresby
# Processing Record 30 of Set 12 | maragogi
# Processing Record 31 of Set 12 | xochistlahuaca
# Processing Record 32 of Set 12 | mehamn
# Processing Record 33 of Set 12 | mogadishu
# Processing Record 34 of Set 12 | makakilo city
# Processing Record 35 of Set 12 | mehran
# Processing Record 36 of Set 12 | luena
# Processing Record 37 of Set 12 | grand gaube
# Processing Record 38 of Set 12 | alice springs
# Processing Record 39 of Set 12 | malaya serdoba
# Processing Record 40 of Set 12 | ballina
# Processing Record 41 of Set 12 | gazojak
# Processing Record 42 of Set 12 | raga
# Processing Record 43 of Set 12 | esperance
# Processing Record 44 of Set 12 | taoudenni
# Processing Record 45 of Set 12 | teknaf
# Processing Record 46 of Set 12 | ojinaga
# Processing Record 47 of Set 12 | sechura
# Processing Record 48 of Set 12 | abbeville
# Processing Record 49 of Set 12 | tual
# Processing Record 50 of Set 12 | jumla
# Processing Record 1 of Set 13 | seddon
# Processing Record 2 of Set 13 | suba
# Processing Record 3 of Set 13 | selma
# Processing Record 4 of Set 13 | nicolas bravo
# Processing Record 5 of Set 13 | kampot
# Processing Record 6 of Set 13 | tezu
# Processing Record 7 of Set 13 | loandjili
# Processing Record 8 of Set 13 | portland
# Processing Record 9 of Set 13 | ciudad guayana
# Processing Record 10 of Set 13 | alikovo
# Processing Record 11 of Set 13 | rawah
# Processing Record 12 of Set 13 | batagay
# Processing Record 13 of Set 13 | hay river
# Processing Record 14 of Set 13 | adre
# Processing Record 15 of Set 13 | marsh harbour
# Processing Record 16 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 13 | den helder
# Processing Record 18 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 13 | adiake
# Processing Record 20 of Set 13 | paita
# Processing Record 21 of Set 13 | awjilah
# Processing Record 22 of Set 13 | maridi
# Processing Record 23 of Set 13 | asheboro
# Processing Record 24 of Set 13 | north auburn
# Processing Record 25 of Set 13 | pustoshka
# Processing Record 26 of Set 13 | nizhniy odes
# Processing Record 27 of Set 13 | hitoyoshi
# Processing Record 28 of Set 13 | lingao
# Processing Record 29 of Set 13 | menemen
# Processing Record 30 of Set 13 | blantyre
# Processing Record 31 of Set 13 | jablanica
# Processing Record 32 of Set 13 | manono
# Processing Record 33 of Set 13 | sharkan
# Processing Record 34 of Set 13 | zhezkazgan
# Processing Record 35 of Set 13 | ruteng
# Processing Record 36 of Set 13 | gweta
# Processing Record 37 of Set 13 | yago
# Processing Record 38 of Set 13 | krasnoselkup
# Processing Record 39 of Set 13 | ruston
# Processing Record 40 of Set 13 | bonthe
# Processing Record 41 of Set 13 | korla
# Processing Record 42 of Set 13 | foster
# Processing Record 43 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 44 of Set 13 | moron
# Processing Record 45 of Set 13 | hailar
# Processing Record 46 of Set 13 | paso de los toros
# Processing Record 47 of Set 13 | det udom
# Processing Record 48 of Set 13 | dalaba
# Processing Record 49 of Set 13 | alekseyevsk
# Processing Record 50 of Set 13 | florianopolis
# Processing Record 1 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 2 of Set 14 | zhanaozen
# Processing Record 3 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 14 | vestmannaeyjar
# Processing Record 5 of Set 14 | rafai
# Processing Record 6 of Set 14 | najran
# Processing Record 7 of Set 14 | moroto
# Processing Record 8 of Set 14 | necochea
# Processing Record 9 of Set 14 | prince rupert
# Processing Record 10 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 11 of Set 14 | sangar
# Processing Record 12 of Set 14 | labytnangi
# Processing Record 13 of Set 14 | akashi
# Processing Record 14 of Set 14 | quebec
# Processing Record 15 of Set 14 | omemee
# Processing Record 16 of Set 14 | farah
# Processing Record 17 of Set 14 | belomorsk
# Processing Record 18 of Set 14 | nemuro
# Processing Record 19 of Set 14 | hvolsvollur
# Processing Record 20 of Set 14 | san jose
# Processing Record 21 of Set 14 | villa constitucion
# Processing Record 22 of Set 14 | luganville
# Processing Record 23 of Set 14 | parry sound
# Processing Record 24 of Set 14 | khandagayty
# Processing Record 25 of Set 14 | filomeno mata
# Processing Record 26 of Set 14 | ponnani
# Processing Record 27 of Set 14 | angoram
# Processing Record 28 of Set 14 | nyaunglebin
# Processing Record 29 of Set 14 | deputatskiy
# Processing Record 30 of Set 14 | tongchuan
# Processing Record 31 of Set 14 | calvinia
# Processing Record 32 of Set 14 | san andres
# Processing Record 33 of Set 14 | ust-koksa
# Processing Record 34 of Set 14 | mount vernon
# Processing Record 35 of Set 14 | barcelos
# Processing Record 36 of Set 14 | maldonado
# Processing Record 37 of Set 14 | muhororo
# Processing Record 38 of Set 14 | belaya gora
# Processing Record 39 of Set 14 | alakurtti
# Processing Record 40 of Set 14 | salta
# Processing Record 41 of Set 14 | maryborough
# Processing Record 42 of Set 14 | raahe
# Processing Record 43 of Set 14 | marquette
# Processing Record 44 of Set 14 | mokhsogollokh
# Processing Record 45 of Set 14 | smolenskoye
# Processing Record 46 of Set 14 | kimberley
# Processing Record 47 of Set 14 | antalaha
# Processing Record 48 of Set 14 | myitkyina
# Processing Record 49 of Set 14 | tikalaan
# City not found. Skipping...
# Processing Record 50 of Set 14 | avera
# Processing Record 1 of Set 15 | gargzdai
# Processing Record 2 of Set 15 | biu
# Processing Record 3 of Set 15 | eyl
# Processing Record 4 of Set 15 | saravan
# Processing Record 5 of Set 15 | broken hill
# Processing Record 6 of Set 15 | maykain
# City not found. Skipping...
# Processing Record 7 of Set 15 | linhares
# Processing Record 8 of Set 15 | kamariotissa
# Processing Record 9 of Set 15 | tigre
# Processing Record 10 of Set 15 | atbasar
# Processing Record 11 of Set 15 | san policarpo
# Processing Record 12 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 15 | saint-denis
# Processing Record 14 of Set 15 | itoman
# Processing Record 15 of Set 15 | shibarghan
# City not found. Skipping...
# Processing Record 16 of Set 15 | san pedro
# Processing Record 17 of Set 15 | constantine
# Processing Record 18 of Set 15 | bonfim
# Processing Record 19 of Set 15 | swanzey
# Processing Record 20 of Set 15 | bilopillya
# Processing Record 21 of Set 15 | wagar
# Processing Record 22 of Set 15 | howard springs
# Processing Record 23 of Set 15 | caraballeda
# Processing Record 24 of Set 15 | ujhani
# Processing Record 25 of Set 15 | valparaiso
# Processing Record 26 of Set 15 | pontianak
# Processing Record 27 of Set 15 | nyandoma
# Processing Record 28 of Set 15 | katobu
# Processing Record 29 of Set 15 | galle
# Processing Record 30 of Set 15 | shache
# Processing Record 31 of Set 15 | garm
# City not found. Skipping...
# Processing Record 32 of Set 15 | shakhrinau
# City not found. Skipping...
# Processing Record 33 of Set 15 | taiyuan
# Processing Record 34 of Set 15 | muli
# Processing Record 35 of Set 15 | riachao das neves
# Processing Record 36 of Set 15 | saint-francois
# Processing Record 37 of Set 15 | jimo
# Processing Record 38 of Set 15 | chute-aux-outardes
# Processing Record 39 of Set 15 | salalah
# Processing Record 40 of Set 15 | kindu
# Processing Record 41 of Set 15 | kenai
# Processing Record 42 of Set 15 | mayskiy
# Processing Record 43 of Set 15 | porto novo
# Processing Record 44 of Set 15 | remedios
# Processing Record 45 of Set 15 | port hawkesbury
# Processing Record 46 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 47 of Set 15 | prieska
# Processing Record 48 of Set 15 | changji
# Processing Record 49 of Set 15 | altamont
# Processing Record 50 of Set 15 | dukat
# Processing Record 1 of Set 16 | mizpe ramon
# City not found. Skipping...
# Processing Record 2 of Set 16 | soyo
# Processing Record 3 of Set 16 | shangzhi
# Processing Record 4 of Set 16 | beloha
# Processing Record 5 of Set 16 | katangli
# Processing Record 6 of Set 16 | ubeda
# Processing Record 7 of Set 16 | cozumel
# Processing Record 8 of Set 16 | port hedland
# Processing Record 9 of Set 16 | fayaoue
# Processing Record 10 of Set 16 | kununurra
# Processing Record 11 of Set 16 | lazarev
# Processing Record 12 of Set 16 | sorland
# Processing Record 13 of Set 16 | shelburne
# Processing Record 14 of Set 16 | ilulissat
# Processing Record 15 of Set 16 | napanee
# Processing Record 16 of Set 16 | doha
# Processing Record 17 of Set 16 | kropotkin
# Processing Record 18 of Set 16 | tabas
# Processing Record 19 of Set 16 | kegayli
# City not found. Skipping...
# Processing Record 20 of Set 16 | svetlogorsk
# Processing Record 21 of Set 16 | minot
# Processing Record 22 of Set 16 | omachi
# Processing Record 23 of Set 16 | maceio
# Processing Record 24 of Set 16 | cururupu
# Processing Record 25 of Set 16 | merauke
# Processing Record 26 of Set 16 | vagur
# Processing Record 27 of Set 16 | dolores
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 709

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     77.00        96          93
# 1      Hermanus -34.4187   19.2345     57.99        88           4
# 2   Yellowknife  62.4560 -114.3525    -31.00        61          40
# 3      Kirakira -10.4544  161.9205     85.19        69          14
# 4       Pulsano  40.3821   17.3564     57.99        71          93
# 5      Mercedes -34.6515  -59.4307     78.01        65           1
# 6   Chaupimarca -10.4333  -76.5333     42.51        93          99
# 7   Tuktoyaktuk  69.4541 -133.0374    -27.40        68          75
# 8     Uglegorsk  49.0833  142.0333      9.07        91         100
# 9     Busselton -33.6500  115.3333     64.00        99          86
#
#    Wind Speed Country Current Description
# 0        4.00      EC     overcast clouds
# 1        1.59      ZA           clear sky
# 2        8.05      CA    scattered clouds
# 3        8.32      SB          few clouds
# 4        1.01      IT          light rain
# 5        1.01      AR           clear sky
# 6        1.59      PE     overcast clouds
# 7       17.27      CA                snow
# 8       17.16      RU          light snow
# 9        1.99      AU     overcast clouds

# %%
# Reorder the columns 
new_column_city_data=['City','Country','Lat','Lng','Max Temp', 'Humidity', 'Cloudiness','Wind Speed', 'Current Description']

# %%
city_data_df = city_data_df[new_column_city_data]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora      EC  -0.7393  -90.3518     77.00        96          93
# 1      Hermanus      ZA -34.4187   19.2345     57.99        88           4
# 2   Yellowknife      CA  62.4560 -114.3525    -31.00        61          40
# 3      Kirakira      SB -10.4544  161.9205     85.19        69          14
# 4       Pulsano      IT  40.3821   17.3564     57.99        71          93
# 5      Mercedes      AR -34.6515  -59.4307     78.01        65           1
# 6   Chaupimarca      PE -10.4333  -76.5333     42.51        93          99
# 7   Tuktoyaktuk      CA  69.4541 -133.0374    -27.40        68          75
# 8     Uglegorsk      RU  49.0833  142.0333      9.07        91         100
# 9     Busselton      AU -33.6500  115.3333     64.00        99          86
#
#    Wind Speed Current Description
# 0        4.00     overcast clouds
# 1        1.59           clear sky
# 2        8.05    scattered clouds
# 3        8.32          few clouds
# 4        1.01          light rain
# 5        1.01           clear sky
# 6        1.59     overcast clouds
# 7       17.27                snow
# 8       17.16          light snow
# 9        1.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-85c3a7d8006d> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# --> 190                 compression=dict(self.compression_args, method=self.compression),
#     191             )
#     192             close = True
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
